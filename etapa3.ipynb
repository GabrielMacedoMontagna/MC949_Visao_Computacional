# %% [markdown]
# # Etapa 3: Emparelhamento de Características (Matching)
#
# **Objetivo:** Utilizar os keypoints e descritores extraídos na Etapa 2 para encontrar correspondências entre pares de imagens consecutivas.
#
# **Pipeline:**
# 1.  **Carregar Dados:** Ler os arquivos `.npz` (keypoints/descritores) e `ordem_imagens.json` da Etapa 2.
# 2.  **Emparelhar (Matching):** Aplicar e comparar dois algoritmos:
#     - **Brute-Force Matcher (BFMatcher):** Compara cada descritor da primeira imagem com todos os da segunda.
#     - **FLANN (Fast Library for Approximate Nearest Neighbors):** Algoritmo otimizado para busca rápida em grandes conjuntos de dados.
# 3.  **Filtrar:** Aplicar o **Ratio Test de David Lowe** para remover correspondências ambíguas e manter apenas os matches de alta confiança.
# 4.  **Salvar Resultados:** Armazenar os matches filtrados em arquivos `.npz` para a Etapa 4 (Cálculo de Homografia).
# 5.  **Visualizar e Analisar:** Gerar imagens de visualização e uma tabela comparativa final.

# %%
import os
import glob
import json
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import List, Tuple
from itertools import combinations 
from fnmatch import fnmatch

# %% [markdown]
# ## Funções Auxiliares (Carregamento, Salvamento e Visualização)

# %%
def desserializar_keypoints(arr: np.ndarray) -> List[cv2.KeyPoint]:
    """
    Reconstrói lista de cv2.KeyPoint a partir do array (N,7).
    """
    kps = []
    for row in arr:
        k = cv2.KeyPoint(
            x=float(row[0]), y=float(row[1]), size=float(row[2]),
            angle=float(row[3]), response=float(row[4]),
            octave=int(row[5]), class_id=int(row[6])
        )
        kps.append(k)
    return kps

def carregar_features_npz(caminho_npz: str) -> Tuple[List[cv2.KeyPoint], np.ndarray, str]:
    """
    Lê um .npz salvo pela Etapa 2 e retorna (keypoints, descriptors, imagem_absoluta).
    """
    with np.load(caminho_npz, allow_pickle=True) as data:
        kps = desserializar_keypoints(data["keypoints"])
        desc = data["descriptors"]
        img_path = str(data["imagem_absoluta"])
    return kps, desc, img_path

def salvar_matches_npz(caminho_saida: str, matches: List[cv2.DMatch]):
    """
    Converte uma lista de matches para um array (N,3) e salva em .npz.
    Colunas: (queryIdx, trainIdx, distance)
    """
    if not matches:
        data = np.zeros((0, 3), dtype=np.float32)
    else:
        data = np.array([[m.queryIdx, m.trainIdx, m.distance] for m in matches], dtype=np.float32)
    np.savez_compressed(caminho_saida, matches=data)

def desenhar_matches_custom(
    img1, kps1, img2, kps2, matches,
    num_matches_a_desenhar=25,
    cor_linha=(255, 0, 255), espessura_linha=3,
    cor_ponto=(0, 255, 0), raio_ponto=15
):
    """Desenha matches entre duas imagens com linhas e pontos customizáveis."""
    h1, w1 = img1.shape[:2]
    h2, w2 = img2.shape[:2]
    output_img = np.zeros((max(h1, h2), w1 + w2, 3), dtype=np.uint8)
    output_img[:h1, :w1] = img1
    output_img[:h2, w1:] = img2

    if kps1 is None or kps2 is None:
        return output_img

    for match in matches[:num_matches_a_desenhar]:
        pt1_idx = match.queryIdx
        pt1 = (int(kps1[pt1_idx].pt[0]), int(kps1[pt1_idx].pt[1]))
        pt2_idx = match.trainIdx
        pt2 = (int(kps2[pt2_idx].pt[0] + w1), int(kps2[pt2_idx].pt[1]))
        cv2.line(output_img, pt1, pt2, cor_linha, espessura_linha)
        cv2.circle(output_img, pt1, raio_ponto, cor_ponto, thickness=-1)
        cv2.circle(output_img, pt2, raio_ponto, cor_ponto, thickness=-1)
        
    return output_img

# %% [markdown]
# ## Funções de Emparelhamento (Matching) e Filtragem

# %%
def criar_matcher(nome_matcher: str, desc_dtype):
    """
    Cria um objeto matcher (BF ou FLANN) configurado corretamente.
    """
    nome_matcher = nome_matcher.lower()

    if nome_matcher == 'bf':
        norm_type = cv2.NORM_L2 if desc_dtype == np.float32 else cv2.NORM_HAMMING
        return cv2.BFMatcher(norm_type)

    if nome_matcher == 'flann':
        if desc_dtype == np.float32:  # Para SIFT
            FLANN_INDEX_KDTREE = 1
            index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
        else:  # Para ORB/AKAZE (descritores binários)
            FLANN_INDEX_LSH = 6
            index_params = dict(
                algorithm=FLANN_INDEX_LSH,
                table_number=6, key_size=12, multi_probe_level=1
            )
        search_params = dict(checks=50)
        return cv2.FlannBasedMatcher(index_params, search_params)

    raise ValueError(f"Matcher '{nome_matcher}' não reconhecido.")


def filtrar_matches_ratio_test(matches_brutos, ratio=0.75):
    """
    Aplica o Ratio Test de David Lowe para filtrar matches ambíguos.
    Requer que os matches tenham sido encontrados com k=2.
    """
    matches_filtrados = []
    # Itera de forma segura, verificando o tamanho de cada resultado
    for match_pair in matches_brutos:
        # Garante que temos 2 vizinhos para desempacotar, evitando o ValueError
        if len(match_pair) == 2:
            m, n = match_pair  # Desempacota somente se for seguro
            if m.distance < ratio * n.distance:
                matches_filtrados.append(m)
    return matches_filtrados

def gerar_pares_indices(n_imagens: int, all_pairs: bool = False, wrap: bool = True):
    """
    Retorna lista de pares (i, j).
    - all_pairs=False: pares sequenciais
      * wrap=True  -> inclui (último, primeiro)
      * wrap=False -> só (0,1), (1,2), ..., (n-2, n-1)
    - all_pairs=True: todas as combinações i<j (sem wrap)
    """
    if n_imagens < 2:
        return []
    if all_pairs:
        return list(combinations(range(n_imagens), 2))  # NEW: todas as combinações i<j
    else:
        if wrap:
            return [(i, (i+1) % n_imagens) for i in range(n_imagens)]
        else:
            return [(i, i+1) for i in range(n_imagens - 1)]
def escolher_conjuntos(raiz: str,
                       only: list[str] | None = None,
                       include_patterns: list[str] | None = None,
                       exclude_patterns: list[str] | None = None) -> list[str]:
    """
    Lista subpastas de 'raiz' aplicando filtros.
    - only: lista explícita (se fornecida, tem prioridade)
    - include_patterns: padrões glob (ex.: ["2024_*", "scene*"])
    - exclude_patterns: padrões glob para excluir
    """
    todos = sorted([d for d in os.listdir(raiz) if os.path.isdir(os.path.join(raiz, d))])
    if only:
        base = [d for d in todos if d in set(only)]
    else:
        base = todos
        if include_patterns:
            base = [d for d in base if any(fnmatch(d, pat) for pat in include_patterns)]
    if exclude_patterns:
        base = [d for d in base if not any(fnmatch(d, pat) for pat in exclude_patterns)]
    return base

# %% [markdown]
# ## Pipeline Principal da Etapa 3

# %%
def analisar_matches_conjunto(caminho_base_etapa2: str, matchers_a_usar: List[str], todos_os_pares: bool = False, salvar_apenas_imgs_de_pares_sequenciais: bool = True):
    """
    Pipeline da Etapa 3: Carrega features, realiza matching, filtra, salva e visualiza.
    Agora inclui o casamento do último com o primeiro (wrap-around).
    Agora pode casar pares sequenciais (com ou sem wrap) ou todas as combinações.
    """
    print(f"\n{'='*65}\nAnalisando Matches para o conjunto: '{os.path.basename(caminho_base_etapa2)}'\n{'='*65}")

    # Carrega a ordem das imagens
    caminho_json = os.path.join(caminho_base_etapa2, "ordem_imagens.json")
    try:
        with open(caminho_json, "r") as f:
            arquivos_de_imagem_abs = json.load(f)
    except FileNotFoundError:
        print(f"[Erro] 'ordem_imagens.json' não encontrado em '{caminho_base_etapa2}'. Abortando.")
        return
    
    # Itera sobre os detectores (sift, orb, etc.)
    detectores = [d for d in os.listdir(caminho_base_etapa2) if os.path.isdir(os.path.join(caminho_base_etapa2, d))]
    for nome_detector in detectores:
        print(f"\n--- Detector: {nome_detector.upper()} ---")
        caminho_detector = os.path.join(caminho_base_etapa2, nome_detector)
        
        # Carrega todos os arquivos de features para este detector
        arquivos_npz = sorted(glob.glob(os.path.join(caminho_detector, "*_features.npz")))
        n = len(arquivos_npz)
        if n < 2:
            continue
        pares = gerar_pares_indices(n, all_pairs=todos_os_pares, wrap=True)

        # Itera sobre os matchers (bf, flann)
        for nome_matcher in matchers_a_usar:
            print(f"  - Matcher: {nome_matcher.upper()}")
            
            # Cria o diretório de saída para esta combinação
            dir_saida = os.path.join("resultados_etapa3", os.path.basename(caminho_base_etapa2), nome_detector, nome_matcher)
            os.makedirs(dir_saida, exist_ok=True)

            # Itera sobre os pares de imagens, incluindo o último com o primeiro
            for (i, j) in pares:
                kps1, desc1, path1 = carregar_features_npz(arquivos_npz[i])
                kps2, desc2, path2 = carregar_features_npz(arquivos_npz[j])

                if desc1 is None or desc2 is None or desc1.shape[0] == 0 or desc2.shape[0] == 0:
                    salvar_matches_npz(os.path.join(dir_saida, f"matches_{i:03d}_{j:03d}.npz"), [])
                    continue

                matcher = criar_matcher(nome_matcher, desc1.dtype)
                matches_brutos = matcher.knnMatch(desc1, desc2, k=2)
                matches_filtrados = filtrar_matches_ratio_test(matches_brutos)
                
                # Salva os matches filtrados para a Etapa 4
                caminho_saida_npz = os.path.join(dir_saida, f"matches_{i:03d}_{j:03d}.npz")
                salvar_matches_npz(caminho_saida_npz, matches_filtrados)


                # Gera preview para TODOS os pares processados e salva como imagem por par
                # (antes o código só gerava o preview para o par 0-1 do SIFT em conjuntos específicos)
                nome_conjunto = os.path.basename(caminho_base_etapa2)
                try:
                    img1 = cv2.imread(path1)
                    img2 = cv2.imread(path2)
                    if img1 is None or img2 is None:
                        print(f"    [Aviso] Não foi possível carregar imagem(s) para preview: {path1}, {path2}")
                    else:
                        if not salvar_apenas_imgs_de_pares_sequenciais or j == (i + 1) % n:
                            print(f"    -> Par {i}-{j}: {len(matches_filtrados)} matches filtrados encontrados. Gerando preview...")
                            preview = desenhar_matches_custom(img1, kps1, img2, kps2, matches_filtrados)
                            caminho_saida_preview = os.path.join(dir_saida, f"preview_matches_filtrados_par_{i:03d}_{j:03d}.jpg")
                            cv2.imwrite(caminho_saida_preview, preview)
                        else:
                            print(f"    -> Par {i}-{j}: {len(matches_filtrados)} matches filtrados encontrados. Ignorando preview.")
                        # opcional: mostrar apenas quando necessário (comente se não quiser output no notebook)
                        # plt.figure(figsize=(20, 10))
                        # plt.imshow(cv2.cvtColor(preview, cv2.COLOR_BGR2RGB))
                        # plt.title(f'Matches Filtrados (Ratio Test) - {nome_detector.upper()}/{nome_matcher.upper()} - {len(matches_filtrados)} matches')
                        # plt.axis('off')
                        # plt.show()
                except Exception as e:
                    print(f"    [Erro] Falha ao gerar preview para o par {i}-{j}: {e}")

# %% [markdown]
# ## Execução do Pipeline para os Conjuntos de Imagens

# %%
RAIZ_ETAPA2 = "resultados_etapa2"
MATCHERS = ['bf', 'flann']

conjuntos = escolher_conjuntos(
    RAIZ_ETAPA2,
    only=None,  # Exemplo: ["images-normal", "images-pro"]
    include_patterns=None,  # Exemplo: ["images_developed*"]
    exclude_patterns=None   # Exemplo: ["images-developed*"]
)

for nome_conjunto in sorted(conjuntos):
    caminho_do_conjunto = os.path.join(RAIZ_ETAPA2, nome_conjunto)
    analisar_matches_conjunto(caminho_do_conjunto, MATCHERS, todos_os_pares=False) #ATENÇÃO, todos_os_pares=True APENAS PARA CALCULO DO GRAFO
# Out:
# =================================================================
# Analisando Matches para o conjunto: 'images-developed-png-16bit'
# =================================================================
#
# --- Detector: ORB ---
#   - Matcher: BF
#     -> Par 0-1: 148 matches filtrados encontrados. Gerando preview...
#     -> Par 0-1: 148 matches filtrados encontrados. Gerando preview...
#     -> Par 0-2: 53 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-2: 53 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-3: 22 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-3: 22 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-4: 26 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-4: 26 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-5: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-5: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-6: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-6: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-7: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-7: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-8: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-8: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-9: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-9: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-11: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-11: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-14: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-14: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-15: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-15: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-17: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-17: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-18: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-18: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-19: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-19: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-21: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-21: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-23: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-23: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-25: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-25: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-27: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-27: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-28: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-28: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-29: 66 matches filtrados encontrados. Ignorando preview.
#     -> Par 0-29: 66 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-2: 121 matches filtrados encontrados. Gerando preview...
#     -> Par 1-2: 121 matches filtrados encontrados. Gerando preview...
#     -> Par 1-3: 85 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-3: 85 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-4: 82 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-4: 82 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-5: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-5: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-6: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-6: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-8: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-8: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-9: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-9: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-12: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-12: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-13: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-13: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-14: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-14: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-15: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-15: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-17: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-17: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-18: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-18: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-21: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-21: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-23: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-23: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-25: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-25: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-26: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-26: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-28: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-28: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-29: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 1-29: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-3: 201 matches filtrados encontrados. Gerando preview...
#     -> Par 2-3: 201 matches filtrados encontrados. Gerando preview...
#     -> Par 2-4: 169 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-4: 169 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-5: 97 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-5: 97 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-6: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-6: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-7: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-7: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-8: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-8: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-10: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-10: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-11: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-11: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-14: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-14: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-16: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-16: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-17: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-17: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-22: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-22: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-23: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-23: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-27: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-27: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-29: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 2-29: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-4: 266 matches filtrados encontrados. Gerando preview...
#     -> Par 3-4: 266 matches filtrados encontrados. Gerando preview...
#     -> Par 3-5: 178 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-5: 178 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-6: 20 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-6: 20 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-8: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-8: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-10: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-10: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-12: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-12: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-13: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-13: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-14: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-14: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-15: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-15: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-16: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-16: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-17: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-17: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-18: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-18: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-20: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-20: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-21: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-21: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-22: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-22: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-28: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-28: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 3-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-5: 156 matches filtrados encontrados. Gerando preview...
#     -> Par 4-5: 156 matches filtrados encontrados. Gerando preview...
#     -> Par 4-6: 28 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-6: 28 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-7: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-8: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-8: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-9: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-9: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-10: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-11: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-12: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-12: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-13: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-13: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-14: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-14: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-22: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-22: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-23: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-23: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-27: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-27: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-28: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-28: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-29: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 4-29: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-6: 68 matches filtrados encontrados. Gerando preview...
#     -> Par 5-6: 68 matches filtrados encontrados. Gerando preview...
#     -> Par 5-7: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-7: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-8: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-8: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-10: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-10: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-11: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-11: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-12: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-12: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-14: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-14: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-15: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-15: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-17: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-17: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-18: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-18: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-19: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-19: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-20: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-20: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-21: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-21: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-22: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-22: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-23: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-23: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-24: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-24: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-26: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-26: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-28: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-28: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 5-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-7: 19 matches filtrados encontrados. Gerando preview...
#     -> Par 6-7: 19 matches filtrados encontrados. Gerando preview...
#     -> Par 6-8: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-8: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-9: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-10: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-10: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-11: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-11: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-12: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-12: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-14: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-14: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-15: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-15: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-16: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-18: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-18: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-19: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-19: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-20: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-22: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-22: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-23: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-23: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-27: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-27: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-29: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-8: 67 matches filtrados encontrados. Gerando preview...
#     -> Par 7-8: 67 matches filtrados encontrados. Gerando preview...
#     -> Par 7-9: 24 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-9: 24 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-10: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-10: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-11: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-11: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-12: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-13: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-14: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-14: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-15: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-15: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-17: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-17: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-18: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-20: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-20: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-22: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-22: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-26: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-26: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-27: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-29: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-29: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-9: 86 matches filtrados encontrados. Gerando preview...
#     -> Par 8-9: 86 matches filtrados encontrados. Gerando preview...
#     -> Par 8-10: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-10: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-11: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-11: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-12: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-12: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-13: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-13: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-14: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-14: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-15: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-15: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-16: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-16: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-18: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-18: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-19: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-21: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-23: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-23: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-25: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-27: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-27: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-28: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-10: 92 matches filtrados encontrados. Gerando preview...
#     -> Par 9-10: 92 matches filtrados encontrados. Gerando preview...
#     -> Par 9-11: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-11: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-12: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-12: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-13: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-14: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-14: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-15: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-16: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-18: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-18: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-19: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-19: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-20: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-21: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-25: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-25: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-26: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-26: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-27: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-27: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-11: 56 matches filtrados encontrados. Gerando preview...
#     -> Par 10-11: 56 matches filtrados encontrados. Gerando preview...
#     -> Par 10-12: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-12: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-13: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-13: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-14: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-14: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-15: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-15: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-16: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-16: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-17: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-17: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-18: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-18: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-19: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-19: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-20: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-20: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-21: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-21: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-22: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-25: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-26: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-26: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-29: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-12: 59 matches filtrados encontrados. Gerando preview...
#     -> Par 11-12: 59 matches filtrados encontrados. Gerando preview...
#     -> Par 11-13: 31 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-13: 31 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-14: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-14: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-15: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-15: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-16: 16 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-16: 16 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-17: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-17: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-18: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-18: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-20: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-20: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-22: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-22: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-23: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-24: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-24: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-26: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-28: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-28: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-29: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-29: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-13: 119 matches filtrados encontrados. Gerando preview...
#     -> Par 12-13: 119 matches filtrados encontrados. Gerando preview...
#     -> Par 12-14: 58 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-14: 58 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-15: 33 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-15: 33 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-16: 27 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-16: 27 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-17: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-17: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-18: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-18: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-19: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-20: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-20: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-21: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-21: 9 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-22: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-22: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-23: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-23: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-24: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-26: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-26: 0 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-27: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-27: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-28: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-28: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-29: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-29: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-14: 89 matches filtrados encontrados. Gerando preview...
#     -> Par 13-14: 89 matches filtrados encontrados. Gerando preview...
#     -> Par 13-15: 43 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-15: 43 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-16: 34 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-16: 34 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-17: 4 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-18: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-18: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-19: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-20: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-20: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-21: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-21: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-22: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-23: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-24: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-25: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-26: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-26: 3 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-27: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-29: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-29: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-15: 61 matches filtrados encontrados. Gerando preview...
#     -> Par 14-15: 61 matches filtrados encontrados. Gerando preview...
#     -> Par 14-16: 36 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-16: 36 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-17: 33 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-17: 33 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-18: 15 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-18: 15 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-19: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-19: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-20: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-20: 19 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-22: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-22: 12 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-23: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-23: 13 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-25: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-25: 6 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-26: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-27: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-27: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-28: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-28: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-29: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-29: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-16: 89 matches filtrados encontrados. Gerando preview...
#     -> Par 15-16: 89 matches filtrados encontrados. Gerando preview...
#     -> Par 15-17: 51 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-17: 51 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-18: 22 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-18: 22 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-19: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-19: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-20: 25 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-20: 25 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-21: 7 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-22: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-22: 17 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-23: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-23: 10 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-24: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-25: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-25: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-26: 2 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-27: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-27: 1 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-28: 5 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-29: 8 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-29: 8 matches filtrados encontrados. Ignorando preview.
# ...
#     -> Par 6-16: 55 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-14: 87 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-15: 78 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-16: 55 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-17: 47 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-18: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-19: 26 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-17: 47 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-18: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-19: 26 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-20: 25 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-21: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-8: 237 matches filtrados encontrados. Gerando preview...
#     -> Par 6-20: 25 matches filtrados encontrados. Ignorando preview.
#     -> Par 6-21: 11 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-8: 237 matches filtrados encontrados. Gerando preview...
#     -> Par 7-9: 218 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-10: 201 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-9: 218 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-10: 201 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-11: 183 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-12: 153 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-11: 183 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-12: 153 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-13: 127 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-14: 115 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-13: 127 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-14: 115 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-15: 99 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-16: 68 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-15: 99 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-16: 68 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-17: 49 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-18: 39 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-17: 49 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-18: 39 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-19: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-20: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-21: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-19: 30 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-20: 32 matches filtrados encontrados. Ignorando preview.
#     -> Par 7-21: 14 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-9: 376 matches filtrados encontrados. Gerando preview...
#     -> Par 8-10: 358 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-9: 376 matches filtrados encontrados. Gerando preview...
#     -> Par 8-10: 358 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-11: 320 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-12: 267 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-13: 217 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-11: 320 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-12: 267 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-13: 217 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-14: 175 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-15: 142 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-14: 175 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-15: 142 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-16: 105 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-17: 85 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-16: 105 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-17: 85 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-18: 81 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-19: 63 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-18: 81 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-19: 63 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-20: 70 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-21: 46 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-20: 70 matches filtrados encontrados. Ignorando preview.
#     -> Par 8-21: 46 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-10: 410 matches filtrados encontrados. Gerando preview...
#     -> Par 9-11: 416 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-10: 410 matches filtrados encontrados. Gerando preview...
#     -> Par 9-11: 416 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-12: 333 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-13: 289 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-14: 219 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-12: 333 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-13: 289 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-14: 219 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-15: 180 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-16: 139 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-15: 180 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-16: 139 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-17: 122 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-18: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-17: 122 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-18: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-19: 112 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-20: 98 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-19: 112 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-20: 98 matches filtrados encontrados. Ignorando preview.
#     -> Par 9-21: 65 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-11: 419 matches filtrados encontrados. Gerando preview...
#     -> Par 9-21: 65 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-11: 419 matches filtrados encontrados. Gerando preview...
#     -> Par 10-12: 365 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-13: 323 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-14: 264 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-12: 365 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-13: 323 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-14: 264 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-15: 220 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-16: 170 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-17: 141 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-15: 220 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-16: 170 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-17: 141 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-18: 124 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-19: 119 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-20: 100 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-18: 124 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-19: 119 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-20: 100 matches filtrados encontrados. Ignorando preview.
#     -> Par 10-21: 72 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-12: 421 matches filtrados encontrados. Gerando preview...
#     -> Par 10-21: 72 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-12: 421 matches filtrados encontrados. Gerando preview...
#     -> Par 11-13: 375 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-14: 298 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-13: 375 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-14: 298 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-15: 260 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-16: 206 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-15: 260 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-16: 206 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-17: 157 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-18: 135 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-17: 157 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-18: 135 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-19: 131 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-20: 109 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-19: 131 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-20: 109 matches filtrados encontrados. Ignorando preview.
#     -> Par 11-21: 78 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-13: 397 matches filtrados encontrados. Gerando preview...
#     -> Par 11-21: 78 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-13: 397 matches filtrados encontrados. Gerando preview...
#     -> Par 12-14: 320 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-15: 283 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-16: 214 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-14: 320 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-15: 283 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-16: 214 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-17: 168 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-18: 145 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-19: 134 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-17: 168 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-18: 145 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-19: 134 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-20: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-21: 89 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-14: 333 matches filtrados encontrados. Gerando preview...
#     -> Par 12-20: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 12-21: 89 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-14: 333 matches filtrados encontrados. Gerando preview...
#     -> Par 13-15: 313 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-16: 247 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-17: 198 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-15: 313 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-16: 247 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-17: 198 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-18: 163 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-19: 138 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-18: 163 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-19: 138 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-20: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-21: 90 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-20: 114 matches filtrados encontrados. Ignorando preview.
#     -> Par 13-21: 90 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-15: 343 matches filtrados encontrados. Gerando preview...
#     -> Par 14-16: 274 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-15: 343 matches filtrados encontrados. Gerando preview...
#     -> Par 14-16: 274 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-17: 225 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-18: 187 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-19: 161 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-17: 225 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-18: 187 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-19: 161 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-20: 138 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-21: 125 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-16: 335 matches filtrados encontrados. Gerando preview...
#     -> Par 14-20: 138 matches filtrados encontrados. Ignorando preview.
#     -> Par 14-21: 125 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-16: 335 matches filtrados encontrados. Gerando preview...
#     -> Par 15-17: 268 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-18: 212 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-19: 183 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-17: 268 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-18: 212 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-19: 183 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-20: 164 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-21: 141 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-20: 164 matches filtrados encontrados. Ignorando preview.
#     -> Par 15-21: 141 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-17: 525 matches filtrados encontrados. Gerando preview...
#     -> Par 16-18: 451 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-17: 525 matches filtrados encontrados. Gerando preview...
#     -> Par 16-18: 451 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-19: 389 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-20: 323 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-21: 285 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-19: 389 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-20: 323 matches filtrados encontrados. Ignorando preview.
#     -> Par 16-21: 285 matches filtrados encontrados. Ignorando preview.
#     -> Par 17-18: 690 matches filtrados encontrados. Gerando preview...
#     -> Par 17-19: 601 matches filtrados encontrados. Ignorando preview.
#     -> Par 17-18: 690 matches filtrados encontrados. Gerando preview...
#     -> Par 17-19: 601 matches filtrados encontrados. Ignorando preview.
#     -> Par 17-20: 523 matches filtrados encontrados. Ignorando preview.
#     -> Par 17-21: 456 matches filtrados encontrados. Ignorando preview.
#     -> Par 18-19: 730 matches filtrados encontrados. Gerando preview...
#     -> Par 17-20: 523 matches filtrados encontrados. Ignorando preview.
#     -> Par 17-21: 456 matches filtrados encontrados. Ignorando preview.
#     -> Par 18-19: 730 matches filtrados encontrados. Gerando preview...
#     -> Par 18-20: 685 matches filtrados encontrados. Ignorando preview.
#     -> Par 18-21: 621 matches filtrados encontrados. Ignorando preview.
#     -> Par 19-20: 814 matches filtrados encontrados. Gerando preview...
#     -> Par 18-20: 685 matches filtrados encontrados. Ignorando preview.
#     -> Par 18-21: 621 matches filtrados encontrados. Ignorando preview.
#     -> Par 19-20: 814 matches filtrados encontrados. Gerando preview...
#     -> Par 19-21: 762 matches filtrados encontrados. Ignorando preview.
#     -> Par 20-21: 816 matches filtrados encontrados. Gerando preview...
#     -> Par 19-21: 762 matches filtrados encontrados. Ignorando preview.
#     -> Par 20-21: 816 matches filtrados encontrados. Gerando preview...

# %% [markdown]
# ## Geração do Relatório Comparativo Final

# %%
def gerar_relatorio_final_etapa3(raiz_resultados: str, only_sequential: bool = True): #only sequential=True só é útil quando calculando os pesos para o grafo
    """Gera uma tabela CSV comparando a média de matches por combinação."""
    print("\nGerando relatório comparativo final da Etapa 3...")
    dados_tabela = []
    
    # Navega pela estrutura de pastas gerada
    for nome_conjunto in sorted(os.listdir(raiz_resultados)):
        caminho_conjunto = os.path.join(raiz_resultados, nome_conjunto)
        if not os.path.isdir(caminho_conjunto): continue
            
        for nome_detector in sorted(os.listdir(caminho_conjunto)):
            caminho_detector = os.path.join(caminho_conjunto, nome_detector)
            if not os.path.isdir(caminho_detector): continue
                
            for nome_matcher in sorted(os.listdir(caminho_detector)):
                caminho_matcher = os.path.join(caminho_detector, nome_matcher)
                if not os.path.isdir(caminho_matcher): continue
                    
                arquivos_matches_npz = glob.glob(os.path.join(caminho_matcher, "matches_*.npz"))
                # NEW: montar pares e, se solicitado, filtrar só sequenciais com wrap
                pares = []
                idxs = set()
                for npz_path in arquivos_matches_npz:
                    base = os.path.splitext(os.path.basename(npz_path))[0]  # matches_000_001
                    _, si, sj = base.split("_")
                    i, j = int(si), int(sj)
                    pares.append((i, j, npz_path))
                    idxs.add(i); idxs.add(j)

                if only_sequential and idxs:
                    n = max(idxs) + 1
                    seq = {(k, (k + 1) % n) for k in range(n)}  # pares sequenciais com wrap
                    pares = [t for t in pares if (t[0], t[1]) in seq]
                    pares.sort(key=lambda t: (t[0], t[1]))  # ordem estável

                if not pares:
                    media_matches = 0.0
                else:
                    contagens = []
                    for _, _, npz in pares:
                        with np.load(npz) as data:
                            contagens.append(len(data['matches']))
                    media_matches = np.mean(contagens)
                
                dados_tabela.append({
                    "conjunto": nome_conjunto,
                    "detector": nome_detector,
                    "matcher": nome_matcher,
                    "media_matches_filtrados_por_par": media_matches
                })
    
    if not dados_tabela:
        print("Nenhum dado encontrado para gerar o relatório.")
        return

    df_final = pd.DataFrame(dados_tabela)
    df_final['media_matches_filtrados_por_par'] = df_final['media_matches_filtrados_por_par'].map('{:,.2f}'.format)
    
    print(f"\n{'='*80}\nRELATÓRIO COMPARATIVO FINAL - ETAPA 3\n{'='*80}")
    
    caminho_saida_final = os.path.join(raiz_resultados, "relatorio_comparativo_matches.csv")
    df_final.to_csv(caminho_saida_final, index=False, sep=';')
    print(f"\nTabela resumo salva em: '{caminho_saida_final}'")
    return df_final

# Execução
gerar_relatorio_final_etapa3("resultados_etapa3", only_sequential=True)
# Out:
# Gerando relatório comparativo final da Etapa 3...
#
# ================================================================================
# RELATÓRIO COMPARATIVO FINAL - ETAPA 3
# ================================================================================
#
# Tabela resumo salva em: 'resultados_etapa3/relatorio_comparativo_matches.csv'
#                        conjunto detector matcher  \
# 0    images-developed-png-16bit    akaze      bf
# 1    images-developed-png-16bit    akaze   flann
# 2    images-developed-png-16bit      orb      bf
# 3    images-developed-png-16bit      orb   flann
# 4    images-developed-png-16bit     sift      bf
# 5    images-developed-png-16bit     sift   flann
# 6     images-developed-png-8bit    akaze      bf
# 7     images-developed-png-8bit    akaze   flann
# 8     images-developed-png-8bit      orb      bf
# 9     images-developed-png-8bit      orb   flann
# 10    images-developed-png-8bit     sift      bf
# 11    images-developed-png-8bit     sift   flann
# 12  images-developed-tiff-16bit    akaze      bf
# 13  images-developed-tiff-16bit    akaze   flann
# 14  images-developed-tiff-16bit      orb      bf
# 15  images-developed-tiff-16bit      orb   flann
# 16  images-developed-tiff-16bit     sift      bf
# 17  images-developed-tiff-16bit     sift   flann
# 18   images-developed-tiff-8bit    akaze      bf
# 19   images-developed-tiff-8bit    akaze   flann
# 20   images-developed-tiff-8bit      orb      bf
# 21   images-developed-tiff-8bit      orb   flann
# 22   images-developed-tiff-8bit     sift      bf
# 23   images-developed-tiff-8bit     sift   flann
# 24                images-normal    akaze      bf
# 25                images-normal    akaze   flann
# 26                images-normal      orb      bf
# 27                images-normal      orb   flann
# 28                images-normal     sift      bf
# 29                images-normal     sift   flann
# 30                   images-pro    akaze      bf
# 31                   images-pro    akaze   flann
# 32                   images-pro      orb      bf
# 33                   images-pro      orb   flann
# 34                   images-pro     sift      bf
# 35                   images-pro     sift   flann
#
#    media_matches_filtrados_por_par
# 0                           297.97
# 1                           303.59
# 2                           117.83
# 3                           126.00
# 4                           166.62
# 5                           167.76
# 6                           295.31
# 7                           300.45
# 8                           118.55
# 9                           127.03
# 10                          165.52
# 11                          166.31
# 12                          294.48
# 13                          299.03
# 14                          118.21
# 15                          126.00
# 16                          166.34
# 17                          167.00
# 18                          294.45
# 19                          299.24
# 20                          117.83
# 21                          125.24
# 22                          164.62
# 23                          165.41
# 24                          651.10
# 25                          653.03
# 26                          305.28
# 27                          309.87
# 28                          281.23
# 29                          281.98
# 30                          472.00
# 31                          474.10
# 32                          217.86
# 33                          223.19
# 34                          238.52
# 35                          238.90
